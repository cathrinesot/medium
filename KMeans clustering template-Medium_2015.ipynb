# %% [markdown]
# # KMeans clustering Medium Articles

# %% [markdown]
# Read in your CSV with the text column if not

# %%
import pandas as pd
# %matplotlib inline
from dirtyclean import clean
import numpy as np
import glob

# %%
df = pd.read_csv("medium_2015.csv", encoding = "ISO-8859-1")

# %%
df.head()
# Out:
#                                                 link  min_read  \
# 0  https://www.google.com/url?q=https://m.signalv...         2
# 1  https://medium.com/@damjancvetkovdimitrov/thes...         5
# 2  https://medium.com/the-year-of-the-looking-gla...         2
# 3  https://medium.com/interactive-mind/mobile-201...         7
# 4  https://medium.com/firm-narrative/want-a-bette...         5
#
#                                             filename                   author  \
# 0  PRESS RELEASE: BASECAMP VALUATION TOPS $100 BI...              Jason Fried
# 1  These photos are why IÕm trapped in Tokyo fore...  Damjan Cvetkov-Dimitrov
# 2                  Average Manager vs. Great Manager               Julie Zhuo
# 3                           Mobile:2015 UI/UX Trends                Onur Oral
# 4                   Want a Better Pitch? Watch This.              Andy Raskin
#
#                     publications  \
# 0                Signal v. Noise
# 1                            NaN
# 2  The Year of the Looking Glass
# 3               Interactive Mind
# 4                            NaN
#
#                                          description       date  followers  \
# 0  Founder & CEO at Basecamp. Co-author of Gettin...   1-Dec-15     205000
# 1  I never anticipate ants.. professionally. I al...  25-Nov-15       2200
# 2                                  Product design VP  11-Aug-15     179000
# 3                                Designer of things.  31-Jul-15       2300
# 4            Helping leaders tell strategic stories.        NaN      20000
#
#    claps  people_clapped                                          high_text  \
# 0   6222            5328  In order to determine the valuation of compani...
# 1   6340            5607                                                NaN
# 2   8700            7034                                                NaN
# 3   4814            4766  Apps which have well-done micro-interactions c...
# 4   7447            6226  ÒIt lacksÊoomph,Ó she said. ÒThe information i...
#
#   images                                               body         tag
# 0    Yes  Basecamp is now a $100 billion dollar company,...     Startup
# 1    Yes  Tokyo, holy excrements from small undefined cr...      Sci-Fy
# 2    Yes                                           Sketches  Management
# 3    Yes  Whether on an app screen, a web browser, or a ...         NaN
# 4    Yes  Three weeks ago, the CMO of a San Francisco st...     Startup

# %%
df.shape
# Out:
# (15, 14)

# %%
df.dtypes
# Out:
# link              object
# min_read           int64
# filename          object
# author            object
# publications      object
# description       object
# date              object
# followers          int64
# claps              int64
# people_clapped     int64
# high_text         object
# images            object
# body              object
# tag               object
# dtype: object

# %%
df["body"] = df["body"].apply(clean)

# %%
df.head()
# Out:
#                                                 link  min_read  \
# 0  https://www.google.com/url?q=https://m.signalv...         2
# 1  https://medium.com/@damjancvetkovdimitrov/thes...         5
# 2  https://medium.com/the-year-of-the-looking-gla...         2
# 3  https://medium.com/interactive-mind/mobile-201...         7
# 4  https://medium.com/firm-narrative/want-a-bette...         5
#
#                                             filename                   author  \
# 0  PRESS RELEASE: BASECAMP VALUATION TOPS $100 BI...              Jason Fried
# 1  These photos are why IÕm trapped in Tokyo fore...  Damjan Cvetkov-Dimitrov
# 2                  Average Manager vs. Great Manager               Julie Zhuo
# 3                           Mobile:2015 UI/UX Trends                Onur Oral
# 4                   Want a Better Pitch? Watch This.              Andy Raskin
#
#                     publications  \
# 0                Signal v. Noise
# 1                            NaN
# 2  The Year of the Looking Glass
# 3               Interactive Mind
# 4                            NaN
#
#                                          description       date  followers  \
# 0  Founder & CEO at Basecamp. Co-author of Gettin...   1-Dec-15     205000
# 1  I never anticipate ants.. professionally. I al...  25-Nov-15       2200
# 2                                  Product design VP  11-Aug-15     179000
# 3                                Designer of things.  31-Jul-15       2300
# 4            Helping leaders tell strategic stories.        NaN      20000
#
#    claps  people_clapped                                          high_text  \
# 0   6222            5328  In order to determine the valuation of compani...
# 1   6340            5607                                                NaN
# 2   8700            7034                                                NaN
# 3   4814            4766  Apps which have well-done micro-interactions c...
# 4   7447            6226  ÒIt lacksÊoomph,Ó she said. ÒThe information i...
#
#   images                                               body         tag
# 0    Yes  Basecamp is now a billion dollar company accor...     Startup
# 1    Yes  Tokyo holy excrements from small undefined cre...      Sci-Fy
# 2    Yes                                           Sketches  Management
# 3    Yes  Whether on an app screen a web browser or a we...         NaN
# 4    Yes  Three weeks ago the CMO of a San Francisco sta...     Startup

# %% [markdown]
# ## Vectorize your documents
#
# What are the options when creating a `TfidfVectorizer`?

# %%
# Out:
# Object `TfidfVectorizer` not found.

# %% [markdown]
# Let's think about:
# * **ngram_range: Do we just want single words? Or more? (1,2) is one- and two-word phrases, etc.
# * **max_features**: Can it make things faster? `1` and up
# * **max_df**: Should we ignore words that show up too often? `0.0`-`1.0` for percent, OR an integer for absolute document counts
# * **min_df**: Should we ignore words that show up too little? `0.0`-`1.0` for percent, OR an integer for absolute document counts
# * **vocabulary**: Only care about certain words
#
# Also... how many documents do we have?

# %%
df.shape
# Out:
# (10, 12)

# %%
# %%time
from sklearn.feature_extraction.text import TfidfVectorizer
from textblob import TextBlob

def textblob_tokenizer(str_input):
    blob = TextBlob(str_input.lower())
    tokens = blob.words
    words = [token.stem() for token in tokens]
    return words

# Vectorize and save into a new dataframe
vec = TfidfVectorizer(tokenizer=textblob_tokenizer,
                      stop_words='english',
                      max_df= 0.9, #if you're in >90%, ignore
                      min_df= 0.15, #if you're in 15%, ignore
                      use_idf=True)

# Fit from the 'text' column of our dataframe
matrix = vec.fit_transform(df['body'])

# Then turn it into a new dataframe
results = pd.DataFrame(matrix.toarray(), columns=vec.get_feature_names())
# Out:
# CPU times: user 1.48 s, sys: 215 ms, total: 1.69 s
# Wall time: 2.25 s

# %%
# %%time
from sklearn.feature_extraction.text import TfidfVectorizer
from textblob import TextBlob
#diwxame to textblob giati argei
def textblob_tokenizer(str_input):
    blob = TextBlob(str_input.lower())
    tokens = blob.words
    words = [token.stem() for token in tokens]
    return words

# Vectorize and save into a new dataframe
vec = TfidfVectorizer(stop_words='english',
                      max_df= 0.9, #if you're in >90%, ignore
                      use_idf=True)

# Fit from the 'text' column of our dataframe
matrix = vec.fit_transform(df['body'])

# Then turn it into a new dataframe
results = pd.DataFrame(matrix.toarray(), columns=vec.get_feature_names())
# Out:
# CPU times: user 44 ms, sys: 1.63 ms, total: 45.6 ms
# Wall time: 48 ms

# %%
results.head()
# Out:
#    aanandamayee  abandon  abc   ability      able  abruptly  absent  \
# 0      0.052774      0.0  0.0  0.000000  0.000000       0.0     0.0
# 1      0.000000      0.0  0.0  0.000000  0.000000       0.0     0.0
# 2      0.000000      0.0  0.0  0.000000  0.000000       0.0     0.0
# 3      0.000000      0.0  0.0  0.040293  0.016298       0.0     0.0
# 4      0.000000      0.0  0.0  0.000000  0.000000       0.0     0.0
#
#    absolutely  abstraction  abundance    ...        ówhat  ówhen  ówhy  \
# 0     0.00000          0.0        0.0    ...     0.000000    0.0   0.0
# 1     0.04564          0.0        0.0    ...     0.000000    0.0   0.0
# 2     0.00000          0.0        0.0    ...     0.000000    0.0   0.0
# 3     0.00000          0.0        0.0    ...     0.000000    0.0   0.0
# 4     0.00000          0.0        0.0    ...     0.037382    0.0   0.0
#
#     ôdepthõ  ôexperimentsõ     ôflat  ôfreeconomicsõ  ôtangibleõ      ôtoo  \
# 0  0.000000       0.000000  0.000000        0.052774    0.000000  0.000000
# 1  0.000000       0.000000  0.000000        0.000000    0.000000  0.000000
# 2  0.000000       0.000000  0.000000        0.000000    0.000000  0.000000
# 3  0.023201       0.023201  0.023201        0.000000    0.023201  0.023201
# 4  0.000000       0.000000  0.000000        0.000000    0.000000  0.000000
#
#       ôwowõ
# 0  0.000000
# 1  0.000000
# 2  0.000000
# 3  0.023201
# 4  0.000000
#
# [5 rows x 3067 columns]

# %% [markdown]
# > ...Try it without the TextBlob tokenizer

# %% [markdown]
# ## Cluster your documents

# %%
# %%time
from sklearn.cluster import KMeans

# How many clusters?
number_of_clusters=3
km = KMeans(n_clusters=number_of_clusters)

print("Fitting", number_of_clusters, "clusters usinga ", matrix.shape, "matrix")

# Let's fit it!
km.fit(matrix)
km.fit
# Out:
# Fitting 3 clusters usinga  (15, 3067) matrix
# CPU times: user 173 ms, sys: 24 ms, total: 197 ms
# Wall time: 247 ms

# %% [markdown]
# ## See what they look like

# %%
print("Top terms per cluster:")
order_centroids = km.cluster_centers_.argsort()[:, ::-1]
terms = vec.get_feature_names()
for i in range(number_of_clusters):
    top_ten_words = [terms[ind] for ind in order_centroids[i, :8]]
    print("Cluster {}: {}".format(i, ' '.join(top_ten_words)))
# Out:
# Top terms per cluster:
# Cluster 0: sketches valuation basecamp musk billion bhatnagar company powerwall
# Cluster 1: work want people books time say morning think
# Cluster 2: today design web internet did tokyo time day

# %% [markdown]
# ## Push the category back to the original dataframe

# %%
df['category'] = km.labels_
df
# Out:
#                                                  link  min_read  \
# 0   https://www.google.com/url?q=https://m.signalv...         2
# 1   https://medium.com/@damjancvetkovdimitrov/thes...         5
# 2   https://medium.com/the-year-of-the-looking-gla...         2
# 3   https://medium.com/interactive-mind/mobile-201...         7
# 4   https://medium.com/firm-narrative/want-a-bette...         5
# 5   https://medium.com/building-asana/work-hard-li...         5
# 6   https://byrslf.co/you-re-only-23-stop-rushing-...         4
# 7   https://medium.com/the-mission/never-tell-peop...         3
# 8   https://medium.com/message/you-are-not-late-b3...         4
# 9   https://medium.com/@tommauchline/15-things-i-l...         3
# 10  https://medium.com/personal-growth/why-you-sho...         3
# 11  https://medium.com/@hughmcguire/why-can-t-we-r...        11
# 12  https://m.signalvnoise.com/give-it-five-minute...         3
# 13  https://medium.com/matter/the-web-we-have-to-s...        16
# 14  https://medium.com/synapse/30-questions-to-ask...         3
#
#                                              filename  \
# 0   PRESS RELEASE: BASECAMP VALUATION TOPS $100 BI...
# 1   These photos are why IÕm trapped in Tokyo fore...
# 2                   Average Manager vs. Great Manager
# 3                            Mobile:2015 UI/UX Trends
# 4                    Want a Better Pitch? Watch This.
# 5                                Work Hard, Live Well
# 6                  YouÕre only 23. Stop rushing life.
# 7                       Never Tell People What You Do
# 8                                    You Are Not Late
# 9   15 things I learnt about Islam and British val...
# 10                 Why You Should Be A Morning Person
# 11                         Why canÕt we read anymore?
# 12                               Give it five minutes
# 13                            The Web We Have to Save
# 14  30 Questions to Ask Your Kid Instead of ÒHow W...
#
#                      author                   publications  \
# 0               Jason Fried                Signal v. Noise
# 1   Damjan Cvetkov-Dimitrov                            NaN
# 2                Julie Zhuo  The Year of the Looking Glass
# 3                 Onur Oral               Interactive Mind
# 4               Andy Raskin                            NaN
# 5          Dustin Moskovitz                 Building Asana
# 6                 Susie Pan                     Life Tips.
# 7            Bruce Kasanoff                  Life Learning
# 8               Kevin Kelly                    The Message
# 9          Thomas Mauchline                            NaN
# 10             Andrew Merle                Personal Growth
# 11             Hugh Mcguire                            NaN
# 12              Jason Fried                Signal v. Noise
# 13       Hossein Derakhshan                         matter
# 14           Sara Goldstein                    The Synapse
#
#                                           description       date  followers  \
# 0   Founder & CEO at Basecamp. Co-author of Gettin...   1-Dec-15     205000
# 1   I never anticipate ants.. professionally. I al...  25-Nov-15       2200
# 2                                   Product design VP  11-Aug-15     179000
# 3                                 Designer of things.  31-Jul-15       2300
# 4             Helping leaders tell strategic stories.        NaN      20000
# 5                                                 NaN  20-Aug-15      16000
# 6   Life wanderer, world traveler, serial entrepre...   9-Dec-15       3100
# 7      Social media ghostwriter. LinkedIn Influencer.   9-Sep-15       3200
# 8   Senior Maverick at Wired, Cool Tools maven, au...  27-Jul-14      15500
# 9   Builds digital campaigns around people and dat...   6-Dec-15        975
# 10  I write about living well, including good habi...   6-Aug-15      10200
# 11  books and/on the web: reb.us, pressbooks.com, ...  22-Apr-15       3600
# 12  Founder & CEO at Basecamp. Co-author of Gettin...  15-Sep-15     205000
# 13  Iranian-Canadian author, blogger. Freed from p...  14-Jul-15       4400
# 14  Real mom, fake adult. Writer and shh-er. Conte...   2-Sep-15       3300
#
#     claps  people_clapped                                          high_text  \
# 0    6222            5328  In order to determine the valuation of compani...
# 1    6340            5607                                                NaN
# 2    8700            7034                                                NaN
# 3    4814            4766  Apps which have well-done micro-interactions c...
# 4    7447            6226  ÒIt lacksÊoomph,Ó she said. ÒThe information i...
# 5    5169            4799  The research is clear: beyond ~40Ð50 hours per...
# 6    5259            5055  As long as I have learned something, and that ...
# 7    4942            4784  When you say what you want, you give others th...
# 8    5894            5255  ÊThere has never been a better time in the who...
# 9    5164            4569  muslims like all British people get flustered ...
# 10   4656            4401  ÊThey tackle the day while others hit the snoo...
# 11   5610            4636  Those who read own the world, and those who wa...
# 12   4723            4424  There are two things in this world that take n...
# 13   8879            4882  The web was not envisioned as a form of televi...
# 14   4073            4048  What was the nicest thing you did for someone ...
#
#    images                                               body  \
# 0     Yes  Basecamp is now a billion dollar company accor...
# 1     Yes  Tokyo holy excrements from small undefined cre...
# 2     Yes                                           Sketches
# 3     Yes  Whether on an app screen a web browser or a we...
# 4     Yes  Three weeks ago the CMO of a San Francisco sta...
# 5     Yes  Amazon isnÕt the only company burning out thei...
# 6     Yes  I asked my CEO today Òwhat can I do to be bett...
# 7     Yes  ItÕs a simple question and youÕve probably ans...
# 8     Yes  Can you imagine how awesome it would have been...
# 9     Yes  No mosque has enough parking and muslim men lo...
# 10    Yes  What is one thing most successful people have ...
# 11    Yes  Last year I read four books The reasons for th...
# 12    Yes  I used to be a hothead Whenever anyone said an...
# 13    Yes  The rich diverse free web that I loved and spe...
# 14     no  When I picked my son up from his first day of ...
#
#                      tag  category
# 0                Startup         0
# 1                 Sci-Fy         2
# 2             Management         0
# 3                    NaN         2
# 4                Startup         0
# 5                   Tech         1
# 6   Personal Development         1
# 7                 Advice         1
# 8                   IMHO         2
# 9                 Muslim         1
# 10               Success         1
# 11                 books         1
# 12               Startup         1
# 13                  Tech         2
# 14             Education         2

# %% [markdown]
# ## Be pleased

# %%
#['said', 'thee', 'ye'] + list(stop_words.ENGLISH_STOP_WORDS)
